# %%
import pandas as pd
from scipy.stats import ks_2samp
import os
import glob

# %%
#path to the validation files
os.chdir('/home/tcs/kaggle/toxic_challenge/correlation_validation/')
#list of files for which you want to do comparison
files=glob.glob('./*test.csv')

def corr(first_file, second_file):
    # assuming first column is `class_name_id`
    print('\n Relation Between : %s and %s' % (first_file,second_file))
    first_df = pd.read_csv(first_file, index_col=0)
    second_df = pd.read_csv(second_file, index_col=0)
    class_names = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

    for class_name in class_names:

        # all correlations
        print('\n Class: %s' % class_name)
        print(' Pearson\'s correlation score: %0.6f' %
              first_df[class_name].corr(
                  second_df[class_name], method='pearson'))
        print(' Kendall\'s correlation score: %0.6f' %
              first_df[class_name].corr(
                  second_df[class_name], method='kendall'))
        print(' Spearman\'s correlation score: %0.6f' %
              first_df[class_name].corr(
                  second_df[class_name], method='spearman'))
        ks_stat, p_value = ks_2samp(first_df[class_name].values,
                                    second_df[class_name].values)
        print(' Kolmogorov-Smirnov test:    KS-stat = %.6f    p-value = %.3e\n'
              % (ks_stat, p_value))

#loop through the files and compare the files one by one with each other
k=0
for i in range(len(files)-1):
    for j in range(i+1,len(files)):
        k=k+1
        corr(files[i],files[j])
print('total number of comparison: %d'%k)
# Out:
#  Relation Between : ./pre_capsule_8_test.csv and ./two_gru_cnn_2_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.967453
#  Kendall's correlation score: 0.838740
#  Spearman's correlation score: 0.957007
#  Kolmogorov-Smirnov test:    KS-stat = 0.354796    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.929144
#  Kendall's correlation score: 0.544047
#  Spearman's correlation score: 0.724219
#  Kolmogorov-Smirnov test:    KS-stat = 0.589695    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.964621
#  Kendall's correlation score: 0.650805
#  Spearman's correlation score: 0.820960
#  Kolmogorov-Smirnov test:    KS-stat = 0.325925    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.858647
#  Kendall's correlation score: 0.586220
#  Spearman's correlation score: 0.777022
#  Kolmogorov-Smirnov test:    KS-stat = 0.498570    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.964549
#  Kendall's correlation score: 0.749615
#  Spearman's correlation score: 0.903686
#  Kolmogorov-Smirnov test:    KS-stat = 0.387056    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.909943
#  Kendall's correlation score: 0.616474
#  Spearman's correlation score: 0.801149
#  Kolmogorov-Smirnov test:    KS-stat = 0.483351    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./clean_dpcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.968987
#  Kendall's correlation score: 0.819468
#  Spearman's correlation score: 0.949966
#  Kolmogorov-Smirnov test:    KS-stat = 0.218256    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.914713
#  Kendall's correlation score: 0.461845
#  Spearman's correlation score: 0.641113
#  Kolmogorov-Smirnov test:    KS-stat = 0.495821    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.943794
#  Kendall's correlation score: 0.720318
#  Spearman's correlation score: 0.882372
#  Kolmogorov-Smirnov test:    KS-stat = 0.342248    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.343728
#  Kendall's correlation score: 0.458566
#  Spearman's correlation score: 0.652003
#  Kolmogorov-Smirnov test:    KS-stat = 0.298249    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.925364
#  Kendall's correlation score: 0.776197
#  Spearman's correlation score: 0.926968
#  Kolmogorov-Smirnov test:    KS-stat = 0.342097    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.515562
#  Kendall's correlation score: 0.511011
#  Spearman's correlation score: 0.713970
#  Kolmogorov-Smirnov test:    KS-stat = 0.260257    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./pre_textcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.977466
#  Kendall's correlation score: 0.828635
#  Spearman's correlation score: 0.956230
#  Kolmogorov-Smirnov test:    KS-stat = 0.277514    p-value = 2.006e-267
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.946391
#  Kendall's correlation score: 0.512787
#  Spearman's correlation score: 0.693187
#  Kolmogorov-Smirnov test:    KS-stat = 0.375051    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.976892
#  Kendall's correlation score: 0.663392
#  Spearman's correlation score: 0.832042
#  Kolmogorov-Smirnov test:    KS-stat = 0.410224    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.882964
#  Kendall's correlation score: 0.575192
#  Spearman's correlation score: 0.767354
#  Kolmogorov-Smirnov test:    KS-stat = 0.191430    p-value = 1.799e-127
#
#
#  Class: insult
#  Pearson's correlation score: 0.967162
#  Kendall's correlation score: 0.757979
#  Spearman's correlation score: 0.912052
#  Kolmogorov-Smirnov test:    KS-stat = 0.411244    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.933400
#  Kendall's correlation score: 0.623645
#  Spearman's correlation score: 0.812487
#  Kolmogorov-Smirnov test:    KS-stat = 0.278509    p-value = 2.419e-269
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./clean_textcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.963941
#  Kendall's correlation score: 0.819434
#  Spearman's correlation score: 0.950425
#  Kolmogorov-Smirnov test:    KS-stat = 0.162460    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.916599
#  Kendall's correlation score: 0.503128
#  Spearman's correlation score: 0.685598
#  Kolmogorov-Smirnov test:    KS-stat = 0.248942    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.949851
#  Kendall's correlation score: 0.667686
#  Spearman's correlation score: 0.838606
#  Kolmogorov-Smirnov test:    KS-stat = 0.319853    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.826461
#  Kendall's correlation score: 0.542161
#  Spearman's correlation score: 0.733144
#  Kolmogorov-Smirnov test:    KS-stat = 0.250764    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.950387
#  Kendall's correlation score: 0.748837
#  Spearman's correlation score: 0.907139
#  Kolmogorov-Smirnov test:    KS-stat = 0.307070    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.900871
#  Kendall's correlation score: 0.616363
#  Spearman's correlation score: 0.805790
#  Kolmogorov-Smirnov test:    KS-stat = 0.197670    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./capsule_2layermax_3_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.977278
#  Kendall's correlation score: 0.864923
#  Spearman's correlation score: 0.967459
#  Kolmogorov-Smirnov test:    KS-stat = 0.410436    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.936283
#  Kendall's correlation score: 0.725103
#  Spearman's correlation score: 0.875193
#  Kolmogorov-Smirnov test:    KS-stat = 0.646105    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.968818
#  Kendall's correlation score: 0.754945
#  Spearman's correlation score: 0.899799
#  Kolmogorov-Smirnov test:    KS-stat = 0.562861    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.627854
#  Kendall's correlation score: 0.647570
#  Spearman's correlation score: 0.822680
#  Kolmogorov-Smirnov test:    KS-stat = 0.708391    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.967673
#  Kendall's correlation score: 0.812248
#  Spearman's correlation score: 0.941668
#  Kolmogorov-Smirnov test:    KS-stat = 0.517341    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.872678
#  Kendall's correlation score: 0.726340
#  Spearman's correlation score: 0.886025
#  Kolmogorov-Smirnov test:    KS-stat = 0.609386    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./wordbatch_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.895114
#  Kendall's correlation score: 0.670424
#  Spearman's correlation score: 0.850661
#  Kolmogorov-Smirnov test:    KS-stat = 0.777187    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.832693
#  Kendall's correlation score: 0.406500
#  Spearman's correlation score: 0.564478
#  Kolmogorov-Smirnov test:    KS-stat = 0.991695    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.906230
#  Kendall's correlation score: 0.530777
#  Spearman's correlation score: 0.705994
#  Kolmogorov-Smirnov test:    KS-stat = 0.869976    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.622168
#  Kendall's correlation score: 0.362477
#  Spearman's correlation score: 0.517063
#  Kolmogorov-Smirnov test:    KS-stat = 0.999001    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.910207
#  Kendall's correlation score: 0.568199
#  Spearman's correlation score: 0.748195
#  Kolmogorov-Smirnov test:    KS-stat = 0.901054    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.772469
#  Kendall's correlation score: 0.472239
#  Spearman's correlation score: 0.652614
#  Kolmogorov-Smirnov test:    KS-stat = 0.988130    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./two_gru_cnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.976630
#  Kendall's correlation score: 0.848191
#  Spearman's correlation score: 0.961105
#  Kolmogorov-Smirnov test:    KS-stat = 0.231497    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.931438
#  Kendall's correlation score: 0.529703
#  Spearman's correlation score: 0.710389
#  Kolmogorov-Smirnov test:    KS-stat = 0.591849    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.968848
#  Kendall's correlation score: 0.694010
#  Spearman's correlation score: 0.856408
#  Kolmogorov-Smirnov test:    KS-stat = 0.302924    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.848672
#  Kendall's correlation score: 0.584069
#  Spearman's correlation score: 0.776522
#  Kolmogorov-Smirnov test:    KS-stat = 0.555960    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.967364
#  Kendall's correlation score: 0.776607
#  Spearman's correlation score: 0.921140
#  Kolmogorov-Smirnov test:    KS-stat = 0.377674    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.924562
#  Kendall's correlation score: 0.615008
#  Spearman's correlation score: 0.800571
#  Kolmogorov-Smirnov test:    KS-stat = 0.506333    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./clean_three_gru_connect6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.980163
#  Kendall's correlation score: 0.855997
#  Spearman's correlation score: 0.963624
#  Kolmogorov-Smirnov test:    KS-stat = 0.257920    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.942533
#  Kendall's correlation score: 0.517166
#  Spearman's correlation score: 0.696490
#  Kolmogorov-Smirnov test:    KS-stat = 0.602929    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.968793
#  Kendall's correlation score: 0.719197
#  Spearman's correlation score: 0.876566
#  Kolmogorov-Smirnov test:    KS-stat = 0.408529    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.879300
#  Kendall's correlation score: 0.544569
#  Spearman's correlation score: 0.732520
#  Kolmogorov-Smirnov test:    KS-stat = 0.529269    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.969107
#  Kendall's correlation score: 0.798090
#  Spearman's correlation score: 0.933683
#  Kolmogorov-Smirnov test:    KS-stat = 0.422998    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.937256
#  Kendall's correlation score: 0.618239
#  Spearman's correlation score: 0.799348
#  Kolmogorov-Smirnov test:    KS-stat = 0.519424    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./clean_two_lstm_cnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.977473
#  Kendall's correlation score: 0.858071
#  Spearman's correlation score: 0.965442
#  Kolmogorov-Smirnov test:    KS-stat = 0.227423    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.940463
#  Kendall's correlation score: 0.511156
#  Spearman's correlation score: 0.693943
#  Kolmogorov-Smirnov test:    KS-stat = 0.538175    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.966174
#  Kendall's correlation score: 0.700449
#  Spearman's correlation score: 0.861569
#  Kolmogorov-Smirnov test:    KS-stat = 0.276024    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.858711
#  Kendall's correlation score: 0.580041
#  Spearman's correlation score: 0.772464
#  Kolmogorov-Smirnov test:    KS-stat = 0.512372    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.967655
#  Kendall's correlation score: 0.784308
#  Spearman's correlation score: 0.925274
#  Kolmogorov-Smirnov test:    KS-stat = 0.342724    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.934420
#  Kendall's correlation score: 0.614428
#  Spearman's correlation score: 0.800430
#  Kolmogorov-Smirnov test:    KS-stat = 0.465638    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./dpcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.968317
#  Kendall's correlation score: 0.822781
#  Spearman's correlation score: 0.951229
#  Kolmogorov-Smirnov test:    KS-stat = 0.246122    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.912656
#  Kendall's correlation score: 0.488441
#  Spearman's correlation score: 0.667297
#  Kolmogorov-Smirnov test:    KS-stat = 0.451686    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.947880
#  Kendall's correlation score: 0.709849
#  Spearman's correlation score: 0.873371
#  Kolmogorov-Smirnov test:    KS-stat = 0.341712    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.340715
#  Kendall's correlation score: 0.479743
#  Spearman's correlation score: 0.674402
#  Kolmogorov-Smirnov test:    KS-stat = 0.330397    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.926484
#  Kendall's correlation score: 0.771156
#  Spearman's correlation score: 0.923432
#  Kolmogorov-Smirnov test:    KS-stat = 0.388838    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.522202
#  Kendall's correlation score: 0.514890
#  Spearman's correlation score: 0.718468
#  Kolmogorov-Smirnov test:    KS-stat = 0.313879    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./three_gru_connect6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.978338
#  Kendall's correlation score: 0.843266
#  Spearman's correlation score: 0.957403
#  Kolmogorov-Smirnov test:    KS-stat = 0.339460    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.937866
#  Kendall's correlation score: 0.541630
#  Spearman's correlation score: 0.715838
#  Kolmogorov-Smirnov test:    KS-stat = 0.609837    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.969224
#  Kendall's correlation score: 0.719039
#  Spearman's correlation score: 0.876599
#  Kolmogorov-Smirnov test:    KS-stat = 0.405141    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.884215
#  Kendall's correlation score: 0.533803
#  Spearman's correlation score: 0.716587
#  Kolmogorov-Smirnov test:    KS-stat = 0.565270    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.969211
#  Kendall's correlation score: 0.790922
#  Spearman's correlation score: 0.929798
#  Kolmogorov-Smirnov test:    KS-stat = 0.476398    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.930024
#  Kendall's correlation score: 0.630468
#  Spearman's correlation score: 0.809563
#  Kolmogorov-Smirnov test:    KS-stat = 0.545716    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./clean_two_gru_cnn_8_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.978449
#  Kendall's correlation score: 0.855486
#  Spearman's correlation score: 0.963828
#  Kolmogorov-Smirnov test:    KS-stat = 0.305052    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.934494
#  Kendall's correlation score: 0.523958
#  Spearman's correlation score: 0.705636
#  Kolmogorov-Smirnov test:    KS-stat = 0.634203    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.968006
#  Kendall's correlation score: 0.706408
#  Spearman's correlation score: 0.865828
#  Kolmogorov-Smirnov test:    KS-stat = 0.359595    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.845251
#  Kendall's correlation score: 0.584070
#  Spearman's correlation score: 0.775321
#  Kolmogorov-Smirnov test:    KS-stat = 0.581814    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.968759
#  Kendall's correlation score: 0.778886
#  Spearman's correlation score: 0.922030
#  Kolmogorov-Smirnov test:    KS-stat = 0.393121    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.928706
#  Kendall's correlation score: 0.623309
#  Spearman's correlation score: 0.807143
#  Kolmogorov-Smirnov test:    KS-stat = 0.557892    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./textcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.961069
#  Kendall's correlation score: 0.815050
#  Spearman's correlation score: 0.948341
#  Kolmogorov-Smirnov test:    KS-stat = 0.195287    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.907098
#  Kendall's correlation score: 0.497324
#  Spearman's correlation score: 0.680616
#  Kolmogorov-Smirnov test:    KS-stat = 0.275554    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.952292
#  Kendall's correlation score: 0.666933
#  Spearman's correlation score: 0.837857
#  Kolmogorov-Smirnov test:    KS-stat = 0.337632    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.809015
#  Kendall's correlation score: 0.535731
#  Spearman's correlation score: 0.728217
#  Kolmogorov-Smirnov test:    KS-stat = 0.265931    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.947777
#  Kendall's correlation score: 0.752974
#  Spearman's correlation score: 0.910372
#  Kolmogorov-Smirnov test:    KS-stat = 0.346870    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.889760
#  Kendall's correlation score: 0.616847
#  Spearman's correlation score: 0.806361
#  Kolmogorov-Smirnov test:    KS-stat = 0.203129    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./pre_two_gru_cnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.992369
#  Kendall's correlation score: 0.876324
#  Spearman's correlation score: 0.975388
#  Kolmogorov-Smirnov test:    KS-stat = 0.253323    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.968777
#  Kendall's correlation score: 0.546061
#  Spearman's correlation score: 0.722862
#  Kolmogorov-Smirnov test:    KS-stat = 0.600827    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.991212
#  Kendall's correlation score: 0.753849
#  Spearman's correlation score: 0.898938
#  Kolmogorov-Smirnov test:    KS-stat = 0.383706    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.876104
#  Kendall's correlation score: 0.597023
#  Spearman's correlation score: 0.791526
#  Kolmogorov-Smirnov test:    KS-stat = 0.585444    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.983624
#  Kendall's correlation score: 0.807713
#  Spearman's correlation score: 0.939137
#  Kolmogorov-Smirnov test:    KS-stat = 0.364661    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.965804
#  Kendall's correlation score: 0.652281
#  Spearman's correlation score: 0.833166
#  Kolmogorov-Smirnov test:    KS-stat = 0.538625    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./two_lstm_cnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.975955
#  Kendall's correlation score: 0.847995
#  Spearman's correlation score: 0.961648
#  Kolmogorov-Smirnov test:    KS-stat = 0.258808    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.934957
#  Kendall's correlation score: 0.507849
#  Spearman's correlation score: 0.691769
#  Kolmogorov-Smirnov test:    KS-stat = 0.568613    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.969054
#  Kendall's correlation score: 0.696716
#  Spearman's correlation score: 0.858495
#  Kolmogorov-Smirnov test:    KS-stat = 0.296930    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.848586
#  Kendall's correlation score: 0.591542
#  Spearman's correlation score: 0.782506
#  Kolmogorov-Smirnov test:    KS-stat = 0.569625    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.966162
#  Kendall's correlation score: 0.767013
#  Spearman's correlation score: 0.914986
#  Kolmogorov-Smirnov test:    KS-stat = 0.388237    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.931716
#  Kendall's correlation score: 0.614542
#  Spearman's correlation score: 0.798844
#  Kolmogorov-Smirnov test:    KS-stat = 0.488457    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./pre_three_gru_connect6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.994389
#  Kendall's correlation score: 0.877540
#  Spearman's correlation score: 0.973572
#  Kolmogorov-Smirnov test:    KS-stat = 0.350285    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.975898
#  Kendall's correlation score: 0.541365
#  Spearman's correlation score: 0.713172
#  Kolmogorov-Smirnov test:    KS-stat = 0.616614    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.993025
#  Kendall's correlation score: 0.781930
#  Spearman's correlation score: 0.918504
#  Kolmogorov-Smirnov test:    KS-stat = 0.494777    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.912649
#  Kendall's correlation score: 0.543625
#  Spearman's correlation score: 0.726721
#  Kolmogorov-Smirnov test:    KS-stat = 0.557357    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.989109
#  Kendall's correlation score: 0.827915
#  Spearman's correlation score: 0.950733
#  Kolmogorov-Smirnov test:    KS-stat = 0.473571    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.970914
#  Kendall's correlation score: 0.661794
#  Spearman's correlation score: 0.836037
#  Kolmogorov-Smirnov test:    KS-stat = 0.537555    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./three_grucnn_1connect3_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.973835
#  Kendall's correlation score: 0.834899
#  Spearman's correlation score: 0.955553
#  Kolmogorov-Smirnov test:    KS-stat = 0.336985    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.925193
#  Kendall's correlation score: 0.520993
#  Spearman's correlation score: 0.700642
#  Kolmogorov-Smirnov test:    KS-stat = 0.689222    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.966854
#  Kendall's correlation score: 0.678808
#  Spearman's correlation score: 0.843733
#  Kolmogorov-Smirnov test:    KS-stat = 0.475490    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.849137
#  Kendall's correlation score: 0.545153
#  Spearman's correlation score: 0.739112
#  Kolmogorov-Smirnov test:    KS-stat = 0.623789    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.964988
#  Kendall's correlation score: 0.763813
#  Spearman's correlation score: 0.912730
#  Kolmogorov-Smirnov test:    KS-stat = 0.505843    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.918566
#  Kendall's correlation score: 0.594964
#  Spearman's correlation score: 0.785972
#  Kolmogorov-Smirnov test:    KS-stat = 0.583336    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_capsule_8_test.csv and ./lgbm_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.928500
#  Kendall's correlation score: 0.696548
#  Spearman's correlation score: 0.871193
#  Kolmogorov-Smirnov test:    KS-stat = 0.243386    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.854790
#  Kendall's correlation score: 0.433908
#  Spearman's correlation score: 0.603317
#  Kolmogorov-Smirnov test:    KS-stat = 0.267328    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.939902
#  Kendall's correlation score: 0.531093
#  Spearman's correlation score: 0.708370
#  Kolmogorov-Smirnov test:    KS-stat = 0.574051    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.705524
#  Kendall's correlation score: 0.438456
#  Spearman's correlation score: 0.617945
#  Kolmogorov-Smirnov test:    KS-stat = 0.391522    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.901572
#  Kendall's correlation score: 0.603710
#  Spearman's correlation score: 0.790638
#  Kolmogorov-Smirnov test:    KS-stat = 0.502233    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.859963
#  Kendall's correlation score: 0.467575
#  Spearman's correlation score: 0.650463
#  Kolmogorov-Smirnov test:    KS-stat = 0.378085    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./clean_dpcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.968121
#  Kendall's correlation score: 0.812359
#  Spearman's correlation score: 0.947047
#  Kolmogorov-Smirnov test:    KS-stat = 0.136729    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.935568
#  Kendall's correlation score: 0.671251
#  Spearman's correlation score: 0.845319
#  Kolmogorov-Smirnov test:    KS-stat = 0.400003    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.954935
#  Kendall's correlation score: 0.678712
#  Spearman's correlation score: 0.848946
#  Kolmogorov-Smirnov test:    KS-stat = 0.039069    p-value = 4.773e-102
#
#
#  Class: threat
#  Pearson's correlation score: 0.318567
#  Kendall's correlation score: 0.645955
#  Spearman's correlation score: 0.846849
#  Kolmogorov-Smirnov test:    KS-stat = 0.356122    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.929582
#  Kendall's correlation score: 0.758767
#  Spearman's correlation score: 0.916346
#  Kolmogorov-Smirnov test:    KS-stat = 0.057083    p-value = 2.332e-217
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.507335
#  Kendall's correlation score: 0.680938
#  Spearman's correlation score: 0.873021
#  Kolmogorov-Smirnov test:    KS-stat = 0.333877    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./pre_textcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.951974
#  Kendall's correlation score: 0.818871
#  Spearman's correlation score: 0.949597
#  Kolmogorov-Smirnov test:    KS-stat = 0.358951    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.939417
#  Kendall's correlation score: 0.760596
#  Spearman's correlation score: 0.915834
#  Kolmogorov-Smirnov test:    KS-stat = 0.535735    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.953117
#  Kendall's correlation score: 0.799590
#  Spearman's correlation score: 0.935927
#  Kolmogorov-Smirnov test:    KS-stat = 0.379658    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.847297
#  Kendall's correlation score: 0.725480
#  Spearman's correlation score: 0.899213
#  Kolmogorov-Smirnov test:    KS-stat = 0.354764    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.949379
#  Kendall's correlation score: 0.804119
#  Spearman's correlation score: 0.940545
#  Kolmogorov-Smirnov test:    KS-stat = 0.422057    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.890929
#  Kendall's correlation score: 0.783163
#  Spearman's correlation score: 0.934541
#  Kolmogorov-Smirnov test:    KS-stat = 0.406692    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./clean_textcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.963531
#  Kendall's correlation score: 0.839772
#  Spearman's correlation score: 0.962028
#  Kolmogorov-Smirnov test:    KS-stat = 0.257417    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.949046
#  Kendall's correlation score: 0.779680
#  Spearman's correlation score: 0.930007
#  Kolmogorov-Smirnov test:    KS-stat = 0.483567    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.971674
#  Kendall's correlation score: 0.810872
#  Spearman's correlation score: 0.943958
#  Kolmogorov-Smirnov test:    KS-stat = 0.299124    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.867332
#  Kendall's correlation score: 0.699710
#  Spearman's correlation score: 0.882481
#  Kolmogorov-Smirnov test:    KS-stat = 0.313285    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.965135
#  Kendall's correlation score: 0.818223
#  Spearman's correlation score: 0.950690
#  Kolmogorov-Smirnov test:    KS-stat = 0.346224    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.938521
#  Kendall's correlation score: 0.795511
#  Spearman's correlation score: 0.942941
#  Kolmogorov-Smirnov test:    KS-stat = 0.311013    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./capsule_2layermax_3_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.979242
#  Kendall's correlation score: 0.861852
#  Spearman's correlation score: 0.970393
#  Kolmogorov-Smirnov test:    KS-stat = 0.479910    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.934178
#  Kendall's correlation score: 0.652217
#  Spearman's correlation score: 0.831468
#  Kolmogorov-Smirnov test:    KS-stat = 0.666403    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.989525
#  Kendall's correlation score: 0.786176
#  Spearman's correlation score: 0.924712
#  Kolmogorov-Smirnov test:    KS-stat = 0.521049    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.540086
#  Kendall's correlation score: 0.567321
#  Spearman's correlation score: 0.772771
#  Kolmogorov-Smirnov test:    KS-stat = 0.677770    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.976274
#  Kendall's correlation score: 0.824104
#  Spearman's correlation score: 0.952399
#  Kolmogorov-Smirnov test:    KS-stat = 0.518562    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.878908
#  Kendall's correlation score: 0.702219
#  Spearman's correlation score: 0.881859
#  Kolmogorov-Smirnov test:    KS-stat = 0.614237    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./wordbatch_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.894717
#  Kendall's correlation score: 0.677188
#  Spearman's correlation score: 0.857101
#  Kolmogorov-Smirnov test:    KS-stat = 0.805640    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.830641
#  Kendall's correlation score: 0.426189
#  Spearman's correlation score: 0.592711
#  Kolmogorov-Smirnov test:    KS-stat = 0.987536    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.894179
#  Kendall's correlation score: 0.543579
#  Spearman's correlation score: 0.720492
#  Kolmogorov-Smirnov test:    KS-stat = 0.861410    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.616049
#  Kendall's correlation score: 0.382228
#  Spearman's correlation score: 0.545114
#  Kolmogorov-Smirnov test:    KS-stat = 0.996115    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.909732
#  Kendall's correlation score: 0.562498
#  Spearman's correlation score: 0.743574
#  Kolmogorov-Smirnov test:    KS-stat = 0.907406    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.759174
#  Kendall's correlation score: 0.510413
#  Spearman's correlation score: 0.697859
#  Kolmogorov-Smirnov test:    KS-stat = 0.984174    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./two_gru_cnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.980133
#  Kendall's correlation score: 0.898600
#  Spearman's correlation score: 0.983480
#  Kolmogorov-Smirnov test:    KS-stat = 0.130599    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.980123
#  Kendall's correlation score: 0.855376
#  Spearman's correlation score: 0.966893
#  Kolmogorov-Smirnov test:    KS-stat = 0.061444    p-value = 8.957e-252
#
#
#  Class: obscene
#  Pearson's correlation score: 0.993918
#  Kendall's correlation score: 0.869022
#  Spearman's correlation score: 0.969968
#  Kolmogorov-Smirnov test:    KS-stat = 0.025966    p-value = 2.597e-45
#
#
#  Class: threat
#  Pearson's correlation score: 0.933867
#  Kendall's correlation score: 0.815107
#  Spearman's correlation score: 0.953935
#  Kolmogorov-Smirnov test:    KS-stat = 0.086424    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.985851
#  Kendall's correlation score: 0.882549
#  Spearman's correlation score: 0.978254
#  Kolmogorov-Smirnov test:    KS-stat = 0.017987    p-value = 5.766e-22
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.973808
#  Kendall's correlation score: 0.872119
#  Spearman's correlation score: 0.976840
#  Kolmogorov-Smirnov test:    KS-stat = 0.039513    p-value = 2.270e-104
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./clean_three_gru_connect6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.974760
#  Kendall's correlation score: 0.849857
#  Spearman's correlation score: 0.963777
#  Kolmogorov-Smirnov test:    KS-stat = 0.146784    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.963348
#  Kendall's correlation score: 0.756767
#  Spearman's correlation score: 0.914088
#  Kolmogorov-Smirnov test:    KS-stat = 0.318521    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.975758
#  Kendall's correlation score: 0.786373
#  Spearman's correlation score: 0.920723
#  Kolmogorov-Smirnov test:    KS-stat = 0.120994    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.924027
#  Kendall's correlation score: 0.702922
#  Spearman's correlation score: 0.884419
#  Kolmogorov-Smirnov test:    KS-stat = 0.265004    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.976825
#  Kendall's correlation score: 0.817211
#  Spearman's correlation score: 0.946398
#  Kolmogorov-Smirnov test:    KS-stat = 0.069540    p-value = 2.273e-322
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.950440
#  Kendall's correlation score: 0.770504
#  Spearman's correlation score: 0.924174
#  Kolmogorov-Smirnov test:    KS-stat = 0.169544    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./clean_two_lstm_cnn_6_test.csv
#  Class: toxic
#  Pearson's correlation score: 0.974672
#  Kendall's correlation score: 0.878180
#  Spearman's correlation score: 0.976472
#  Kolmogorov-Smirnov test:    KS-stat = 0.134731    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.973303
#  Kendall's correlation score: 0.833944
#  Spearman's correlation score: 0.958212
#  Kolmogorov-Smirnov test:    KS-stat = 0.189287    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.979222
#  Kendall's correlation score: 0.839116
#  Spearman's correlation score: 0.955841
#  Kolmogorov-Smirnov test:    KS-stat = 0.054053    p-value = 6.059e-195
#
#
#  Class: threat
#  Pearson's correlation score: 0.916850
#  Kendall's correlation score: 0.812510
#  Spearman's correlation score: 0.952133
#  Kolmogorov-Smirnov test:    KS-stat = 0.087658    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.979633
#  Kendall's correlation score: 0.873027
#  Spearman's correlation score: 0.974571
#  Kolmogorov-Smirnov test:    KS-stat = 0.057827    p-value = 4.716e-223
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.958974
#  Kendall's correlation score: 0.856744
#  Spearman's correlation score: 0.970614
#  Kolmogorov-Smirnov test:    KS-stat = 0.060132    p-value = 3.751e-241
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./dpcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.976362
#  Kendall's correlation score: 0.840211
#  Spearman's correlation score: 0.961603
#  Kolmogorov-Smirnov test:    KS-stat = 0.108825    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.940239
#  Kendall's correlation score: 0.695052
#  Spearman's correlation score: 0.865528
#  Kolmogorov-Smirnov test:    KS-stat = 0.436291    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.967938
#  Kendall's correlation score: 0.735887
#  Spearman's correlation score: 0.892839
#  Kolmogorov-Smirnov test:    KS-stat = 0.036549    p-value = 2.325e-89
#
#
#  Class: threat
#  Pearson's correlation score: 0.323649
#  Kendall's correlation score: 0.675296
#  Spearman's correlation score: 0.870816
#  Kolmogorov-Smirnov test:    KS-stat = 0.362370    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.936409
#  Kendall's correlation score: 0.799193
#  Spearman's correlation score: 0.941785
#  Kolmogorov-Smirnov test:    KS-stat = 0.036497    p-value = 4.172e-89
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.519407
#  Kendall's correlation score: 0.713066
#  Spearman's correlation score: 0.896718
#  Kolmogorov-Smirnov test:    KS-stat = 0.318012    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./three_gru_connect6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.977237
#  Kendall's correlation score: 0.876898
#  Spearman's correlation score: 0.974288
#  Kolmogorov-Smirnov test:    KS-stat = 0.099913    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.966552
#  Kendall's correlation score: 0.703442
#  Spearman's correlation score: 0.867994
#  Kolmogorov-Smirnov test:    KS-stat = 0.355397    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.989612
#  Kendall's correlation score: 0.805144
#  Spearman's correlation score: 0.930194
#  Kolmogorov-Smirnov test:    KS-stat = 0.092385    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.935211
#  Kendall's correlation score: 0.674909
#  Spearman's correlation score: 0.857756
#  Kolmogorov-Smirnov test:    KS-stat = 0.273661    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.981503
#  Kendall's correlation score: 0.828108
#  Spearman's correlation score: 0.950291
#  Kolmogorov-Smirnov test:    KS-stat = 0.161702    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.945518
#  Kendall's correlation score: 0.745676
#  Spearman's correlation score: 0.904090
#  Kolmogorov-Smirnov test:    KS-stat = 0.157348    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./clean_two_gru_cnn_8_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.978174
#  Kendall's correlation score: 0.885445
#  Spearman's correlation score: 0.978737
#  Kolmogorov-Smirnov test:    KS-stat = 0.052401    p-value = 3.086e-183
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.973596
#  Kendall's correlation score: 0.841641
#  Spearman's correlation score: 0.960812
#  Kolmogorov-Smirnov test:    KS-stat = 0.152588    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.982105
#  Kendall's correlation score: 0.840431
#  Spearman's correlation score: 0.956195
#  Kolmogorov-Smirnov test:    KS-stat = 0.048758    p-value = 1.060e-158
#
#
#  Class: threat
#  Pearson's correlation score: 0.920658
#  Kendall's correlation score: 0.810980
#  Spearman's correlation score: 0.951265
#  Kolmogorov-Smirnov test:    KS-stat = 0.099266    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.982065
#  Kendall's correlation score: 0.879441
#  Spearman's correlation score: 0.976623
#  Kolmogorov-Smirnov test:    KS-stat = 0.029583    p-value = 1.091e-58
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.963250
#  Kendall's correlation score: 0.863505
#  Spearman's correlation score: 0.973019
#  Kolmogorov-Smirnov test:    KS-stat = 0.151008    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./textcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.964529
#  Kendall's correlation score: 0.845338
#  Spearman's correlation score: 0.964926
#  Kolmogorov-Smirnov test:    KS-stat = 0.287444    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.953927
#  Kendall's correlation score: 0.786260
#  Spearman's correlation score: 0.933871
#  Kolmogorov-Smirnov test:    KS-stat = 0.502683    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.983474
#  Kendall's correlation score: 0.817656
#  Spearman's correlation score: 0.947822
#  Kolmogorov-Smirnov test:    KS-stat = 0.315472    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.858101
#  Kendall's correlation score: 0.701326
#  Spearman's correlation score: 0.884437
#  Kolmogorov-Smirnov test:    KS-stat = 0.313951    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.968255
#  Kendall's correlation score: 0.817213
#  Spearman's correlation score: 0.950047
#  Kolmogorov-Smirnov test:    KS-stat = 0.376799    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.936284
#  Kendall's correlation score: 0.794193
#  Spearman's correlation score: 0.942557
#  Kolmogorov-Smirnov test:    KS-stat = 0.366979    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./pre_two_gru_cnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.967624
#  Kendall's correlation score: 0.851308
#  Spearman's correlation score: 0.962981
#  Kolmogorov-Smirnov test:    KS-stat = 0.116516    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.947537
#  Kendall's correlation score: 0.816505
#  Spearman's correlation score: 0.944888
#  Kolmogorov-Smirnov test:    KS-stat = 0.065577    p-value = 1.006e-286
#
#
#  Class: obscene
#  Pearson's correlation score: 0.966981
#  Kendall's correlation score: 0.793641
#  Spearman's correlation score: 0.928929
#  Kolmogorov-Smirnov test:    KS-stat = 0.060066    p-value = 1.249e-240
#
#
#  Class: threat
#  Pearson's correlation score: 0.885663
#  Kendall's correlation score: 0.784705
#  Spearman's correlation score: 0.934378
#  Kolmogorov-Smirnov test:    KS-stat = 0.115353    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.963437
#  Kendall's correlation score: 0.844292
#  Spearman's correlation score: 0.960020
#  Kolmogorov-Smirnov test:    KS-stat = 0.043561    p-value = 9.286e-127
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.920910
#  Kendall's correlation score: 0.826588
#  Spearman's correlation score: 0.953531
#  Kolmogorov-Smirnov test:    KS-stat = 0.080352    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./two_lstm_cnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.984439
#  Kendall's correlation score: 0.893056
#  Spearman's correlation score: 0.982340
#  Kolmogorov-Smirnov test:    KS-stat = 0.101891    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.976538
#  Kendall's correlation score: 0.825550
#  Spearman's correlation score: 0.952739
#  Kolmogorov-Smirnov test:    KS-stat = 0.132975    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.991487
#  Kendall's correlation score: 0.853738
#  Spearman's correlation score: 0.963266
#  Kolmogorov-Smirnov test:    KS-stat = 0.046179    p-value = 2.117e-142
#
#
#  Class: threat
#  Pearson's correlation score: 0.931411
#  Kendall's correlation score: 0.827696
#  Spearman's correlation score: 0.959242
#  Kolmogorov-Smirnov test:    KS-stat = 0.099384    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.985899
#  Kendall's correlation score: 0.888564
#  Spearman's correlation score: 0.980949
#  Kolmogorov-Smirnov test:    KS-stat = 0.022597    p-value = 2.026e-34
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.971893
#  Kendall's correlation score: 0.878618
#  Spearman's correlation score: 0.979441
#  Kolmogorov-Smirnov test:    KS-stat = 0.015826    p-value = 4.225e-17
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./pre_three_gru_connect6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.965478
#  Kendall's correlation score: 0.839494
#  Spearman's correlation score: 0.956253
#  Kolmogorov-Smirnov test:    KS-stat = 0.081645    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.937022
#  Kendall's correlation score: 0.706674
#  Spearman's correlation score: 0.875856
#  Kolmogorov-Smirnov test:    KS-stat = 0.348868    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.965592
#  Kendall's correlation score: 0.719535
#  Spearman's correlation score: 0.874906
#  Kolmogorov-Smirnov test:    KS-stat = 0.277950    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.895261
#  Kendall's correlation score: 0.668532
#  Spearman's correlation score: 0.852527
#  Kolmogorov-Smirnov test:    KS-stat = 0.267302    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.960726
#  Kendall's correlation score: 0.794859
#  Spearman's correlation score: 0.931089
#  Kolmogorov-Smirnov test:    KS-stat = 0.153496    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.914818
#  Kendall's correlation score: 0.719499
#  Spearman's correlation score: 0.888635
#  Kolmogorov-Smirnov test:    KS-stat = 0.154449    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./three_grucnn_1connect3_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.970428
#  Kendall's correlation score: 0.866344
#  Spearman's correlation score: 0.971638
#  Kolmogorov-Smirnov test:    KS-stat = 0.088415    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.959129
#  Kendall's correlation score: 0.812535
#  Spearman's correlation score: 0.947522
#  Kolmogorov-Smirnov test:    KS-stat = 0.443969    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.990708
#  Kendall's correlation score: 0.832364
#  Spearman's correlation score: 0.953654
#  Kolmogorov-Smirnov test:    KS-stat = 0.282168    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.905256
#  Kendall's correlation score: 0.761707
#  Spearman's correlation score: 0.923109
#  Kolmogorov-Smirnov test:    KS-stat = 0.298712    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.976878
#  Kendall's correlation score: 0.844842
#  Spearman's correlation score: 0.962143
#  Kolmogorov-Smirnov test:    KS-stat = 0.307566    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.961216
#  Kendall's correlation score: 0.819474
#  Spearman's correlation score: 0.955435
#  Kolmogorov-Smirnov test:    KS-stat = 0.300978    p-value = 0.000e+00
#
#
#  Relation Between : ./two_gru_cnn_2_test.csv and ./lgbm_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.927916
#  Kendall's correlation score: 0.706814
#  Spearman's correlation score: 0.880192
#  Kolmogorov-Smirnov test:    KS-stat = 0.337775    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.852332
#  Kendall's correlation score: 0.587243
#  Spearman's correlation score: 0.775106
#  Kolmogorov-Smirnov test:    KS-stat = 0.556985    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.936627
#  Kendall's correlation score: 0.647457
#  Spearman's correlation score: 0.824022
#  Kolmogorov-Smirnov test:    KS-stat = 0.533951    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.706019
#  Kendall's correlation score: 0.496874
#  Spearman's correlation score: 0.687178
#  Kolmogorov-Smirnov test:    KS-stat = 0.392605    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.906402
#  Kendall's correlation score: 0.654450
#  Spearman's correlation score: 0.837069
#  Kolmogorov-Smirnov test:    KS-stat = 0.497591    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.811600
#  Kendall's correlation score: 0.582599
#  Spearman's correlation score: 0.774681
#  Kolmogorov-Smirnov test:    KS-stat = 0.507430    p-value = 0.000e+00
#
#
#  Relation Between : ./clean_dpcnn_6_test.csv and ./pre_textcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.955293
#  Kendall's correlation score: 0.770295
#  Spearman's correlation score: 0.922996
#  Kolmogorov-Smirnov test:    KS-stat = 0.242425    p-value = 3.563e-204
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.910805
#  Kendall's correlation score: 0.635553
#  Spearman's correlation score: 0.816978
#  Kolmogorov-Smirnov test:    KS-stat = 0.445667    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.928176
#  Kendall's correlation score: 0.669300
#  Spearman's correlation score: 0.843659
#  Kolmogorov-Smirnov test:    KS-stat = 0.378365    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.375007
#  Kendall's correlation score: 0.580794
#  Spearman's correlation score: 0.781875
#  Kolmogorov-Smirnov test:    KS-stat = 0.152926    p-value = 1.673e-81
#
#
#  Class: insult
#  Pearson's correlation score: 0.929171
#  Kendall's correlation score: 0.741212
#  Spearman's correlation score: 0.902893
#  Kolmogorov-Smirnov test:    KS-stat = 0.394764    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.595323
#  Kendall's correlation score: 0.629566
#  Spearman's correlation score: 0.825271
#  Kolmogorov-Smirnov test:    KS-stat = 0.226534    p-value = 2.443e-178
#
#
#  Relation Between : ./clean_dpcnn_6_test.csv and ./clean_textcnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.976186
#  Kendall's correlation score: 0.805012
#  Spearman's correlation score: 0.943846
# ...
#
#
#  Relation Between : ./textcnn_6_test.csv and ./three_grucnn_1connect3_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.978246
#  Kendall's correlation score: 0.837486
#  Spearman's correlation score: 0.961330
#  Kolmogorov-Smirnov test:    KS-stat = 0.263273    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.940300
#  Kendall's correlation score: 0.777196
#  Spearman's correlation score: 0.928539
#  Kolmogorov-Smirnov test:    KS-stat = 0.640980    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.979744
#  Kendall's correlation score: 0.800862
#  Spearman's correlation score: 0.938646
#  Kolmogorov-Smirnov test:    KS-stat = 0.437427    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.850310
#  Kendall's correlation score: 0.677886
#  Spearman's correlation score: 0.865007
#  Kolmogorov-Smirnov test:    KS-stat = 0.496213    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.970402
#  Kendall's correlation score: 0.811926
#  Spearman's correlation score: 0.947692
#  Kolmogorov-Smirnov test:    KS-stat = 0.479101    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.918584
#  Kendall's correlation score: 0.764912
#  Spearman's correlation score: 0.926258
#  Kolmogorov-Smirnov test:    KS-stat = 0.506705    p-value = 0.000e+00
#
#
#  Relation Between : ./textcnn_6_test.csv and ./lgbm_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.921165
#  Kendall's correlation score: 0.714574
#  Spearman's correlation score: 0.886695
#  Kolmogorov-Smirnov test:    KS-stat = 0.053707    p-value = 1.841e-192
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.849322
#  Kendall's correlation score: 0.565490
#  Spearman's correlation score: 0.753422
#  Kolmogorov-Smirnov test:    KS-stat = 0.113878    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.934361
#  Kendall's correlation score: 0.637208
#  Spearman's correlation score: 0.815529
#  Kolmogorov-Smirnov test:    KS-stat = 0.309616    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.751406
#  Kendall's correlation score: 0.504673
#  Spearman's correlation score: 0.697471
#  Kolmogorov-Smirnov test:    KS-stat = 0.244548    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.899802
#  Kendall's correlation score: 0.656167
#  Spearman's correlation score: 0.838411
#  Kolmogorov-Smirnov test:    KS-stat = 0.199538    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.813670
#  Kendall's correlation score: 0.591646
#  Spearman's correlation score: 0.784322
#  Kolmogorov-Smirnov test:    KS-stat = 0.198173    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_two_gru_cnn_6_test.csv and ./two_lstm_cnn_6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.976916
#  Kendall's correlation score: 0.859184
#  Spearman's correlation score: 0.966917
#  Kolmogorov-Smirnov test:    KS-stat = 0.020769    p-value = 3.841e-29
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.953948
#  Kendall's correlation score: 0.851518
#  Spearman's correlation score: 0.962839
#  Kolmogorov-Smirnov test:    KS-stat = 0.075827    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.970369
#  Kendall's correlation score: 0.841819
#  Spearman's correlation score: 0.956874
#  Kolmogorov-Smirnov test:    KS-stat = 0.096184    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.942099
#  Kendall's correlation score: 0.818992
#  Spearman's correlation score: 0.950800
#  Kolmogorov-Smirnov test:    KS-stat = 0.038612    p-value = 1.103e-99
#
#
#  Class: insult
#  Pearson's correlation score: 0.971099
#  Kendall's correlation score: 0.859707
#  Spearman's correlation score: 0.966827
#  Kolmogorov-Smirnov test:    KS-stat = 0.063207    p-value = 2.103e-266
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.945756
#  Kendall's correlation score: 0.844946
#  Spearman's correlation score: 0.961989
#  Kolmogorov-Smirnov test:    KS-stat = 0.082239    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_two_gru_cnn_6_test.csv and ./pre_three_gru_connect6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.993844
#  Kendall's correlation score: 0.890617
#  Spearman's correlation score: 0.979741
#  Kolmogorov-Smirnov test:    KS-stat = 0.109210    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.979342
#  Kendall's correlation score: 0.805057
#  Spearman's correlation score: 0.941302
#  Kolmogorov-Smirnov test:    KS-stat = 0.313533    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.993136
#  Kendall's correlation score: 0.846998
#  Spearman's correlation score: 0.960386
#  Kolmogorov-Smirnov test:    KS-stat = 0.258207    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.926106
#  Kendall's correlation score: 0.738564
#  Spearman's correlation score: 0.908084
#  Kolmogorov-Smirnov test:    KS-stat = 0.316576    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.988561
#  Kendall's correlation score: 0.871087
#  Spearman's correlation score: 0.969872
#  Kolmogorov-Smirnov test:    KS-stat = 0.196110    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.970631
#  Kendall's correlation score: 0.800374
#  Spearman's correlation score: 0.941578
#  Kolmogorov-Smirnov test:    KS-stat = 0.232431    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_two_gru_cnn_6_test.csv and ./three_grucnn_1connect3_test.csv
#  Class: toxic
#  Pearson's correlation score: 0.974465
#  Kendall's correlation score: 0.843144
#  Spearman's correlation score: 0.960273
#  Kolmogorov-Smirnov test:    KS-stat = 0.155063    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.936749
#  Kendall's correlation score: 0.809593
#  Spearman's correlation score: 0.944107
#  Kolmogorov-Smirnov test:    KS-stat = 0.491134    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.970173
#  Kendall's correlation score: 0.819098
#  Spearman's correlation score: 0.946172
#  Kolmogorov-Smirnov test:    KS-stat = 0.282906    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.904782
#  Kendall's correlation score: 0.747484
#  Spearman's correlation score: 0.913128
#  Kolmogorov-Smirnov test:    KS-stat = 0.278460    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.966681
#  Kendall's correlation score: 0.838916
#  Spearman's correlation score: 0.958224
#  Kolmogorov-Smirnov test:    KS-stat = 0.332284    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.933220
#  Kendall's correlation score: 0.810324
#  Spearman's correlation score: 0.947135
#  Kolmogorov-Smirnov test:    KS-stat = 0.254838    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_two_gru_cnn_6_test.csv and ./lgbm_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.928200
#  Kendall's correlation score: 0.689375
#  Spearman's correlation score: 0.864868
#  Kolmogorov-Smirnov test:    KS-stat = 0.254538    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.864270
#  Kendall's correlation score: 0.528582
#  Spearman's correlation score: 0.710776
#  Kolmogorov-Smirnov test:    KS-stat = 0.565707    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.938044
#  Kendall's correlation score: 0.609481
#  Spearman's correlation score: 0.787148
#  Kolmogorov-Smirnov test:    KS-stat = 0.561672    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.773053
#  Kendall's correlation score: 0.503465
#  Spearman's correlation score: 0.694183
#  Kolmogorov-Smirnov test:    KS-stat = 0.464150    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.902330
#  Kendall's correlation score: 0.638569
#  Spearman's correlation score: 0.821567
#  Kolmogorov-Smirnov test:    KS-stat = 0.489808    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.857440
#  Kendall's correlation score: 0.558871
#  Spearman's correlation score: 0.748954
#  Kolmogorov-Smirnov test:    KS-stat = 0.557403    p-value = 0.000e+00
#
#
#  Relation Between : ./two_lstm_cnn_6_test.csv and ./pre_three_gru_connect6_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.977796
#  Kendall's correlation score: 0.849528
#  Spearman's correlation score: 0.962048
#  Kolmogorov-Smirnov test:    KS-stat = 0.097347    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.950958
#  Kendall's correlation score: 0.781896
#  Spearman's correlation score: 0.928917
#  Kolmogorov-Smirnov test:    KS-stat = 0.261060    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.970533
#  Kendall's correlation score: 0.788798
#  Spearman's correlation score: 0.929439
#  Kolmogorov-Smirnov test:    KS-stat = 0.322824    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.899265
#  Kendall's correlation score: 0.710760
#  Spearman's correlation score: 0.884920
#  Kolmogorov-Smirnov test:    KS-stat = 0.291367    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.968995
#  Kendall's correlation score: 0.819579
#  Spearman's correlation score: 0.943426
#  Kolmogorov-Smirnov test:    KS-stat = 0.133778    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.942691
#  Kendall's correlation score: 0.749605
#  Spearman's correlation score: 0.909612
#  Kolmogorov-Smirnov test:    KS-stat = 0.150943    p-value = 0.000e+00
#
#
#  Relation Between : ./two_lstm_cnn_6_test.csv and ./three_grucnn_1connect3_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.987687
#  Kendall's correlation score: 0.880145
#  Spearman's correlation score: 0.977184
#  Kolmogorov-Smirnov test:    KS-stat = 0.135920    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.970521
#  Kendall's correlation score: 0.830241
#  Spearman's correlation score: 0.957848
#  Kolmogorov-Smirnov test:    KS-stat = 0.518444    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.992186
#  Kendall's correlation score: 0.869145
#  Spearman's correlation score: 0.972048
#  Kolmogorov-Smirnov test:    KS-stat = 0.322615    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.928188
#  Kendall's correlation score: 0.784027
#  Spearman's correlation score: 0.936368
#  Kolmogorov-Smirnov test:    KS-stat = 0.309988    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.984432
#  Kendall's correlation score: 0.868923
#  Spearman's correlation score: 0.972724
#  Kolmogorov-Smirnov test:    KS-stat = 0.292882    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.975153
#  Kendall's correlation score: 0.840967
#  Spearman's correlation score: 0.965121
#  Kolmogorov-Smirnov test:    KS-stat = 0.311189    p-value = 0.000e+00
#
#
#  Relation Between : ./two_lstm_cnn_6_test.csv and ./lgbm_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.926813
#  Kendall's correlation score: 0.706569
#  Spearman's correlation score: 0.880071
#  Kolmogorov-Smirnov test:    KS-stat = 0.254335    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.854023
#  Kendall's correlation score: 0.526324
#  Spearman's correlation score: 0.710636
#  Kolmogorov-Smirnov test:    KS-stat = 0.531391    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.940028
#  Kendall's correlation score: 0.630180
#  Spearman's correlation score: 0.807762
#  Kolmogorov-Smirnov test:    KS-stat = 0.518816    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.770416
#  Kendall's correlation score: 0.505412
#  Spearman's correlation score: 0.697306
#  Kolmogorov-Smirnov test:    KS-stat = 0.446606    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.907407
#  Kendall's correlation score: 0.653067
#  Spearman's correlation score: 0.836078
#  Kolmogorov-Smirnov test:    KS-stat = 0.487301    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.838537
#  Kendall's correlation score: 0.573251
#  Spearman's correlation score: 0.765316
#  Kolmogorov-Smirnov test:    KS-stat = 0.511772    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_three_gru_connect6_test.csv and ./three_grucnn_1connect3_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.975802
#  Kendall's correlation score: 0.832572
#  Spearman's correlation score: 0.954664
#  Kolmogorov-Smirnov test:    KS-stat = 0.157792    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.944269
#  Kendall's correlation score: 0.751710
#  Spearman's correlation score: 0.908653
#  Kolmogorov-Smirnov test:    KS-stat = 0.604646    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.970532
#  Kendall's correlation score: 0.769574
#  Spearman's correlation score: 0.916762
#  Kolmogorov-Smirnov test:    KS-stat = 0.269835    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.902426
#  Kendall's correlation score: 0.729136
#  Spearman's correlation score: 0.899922
#  Kolmogorov-Smirnov test:    KS-stat = 0.492981    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.970889
#  Kendall's correlation score: 0.811804
#  Spearman's correlation score: 0.942181
#  Kolmogorov-Smirnov test:    KS-stat = 0.351075    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.933469
#  Kendall's correlation score: 0.748121
#  Spearman's correlation score: 0.909673
#  Kolmogorov-Smirnov test:    KS-stat = 0.428188    p-value = 0.000e+00
#
#
#  Relation Between : ./pre_three_gru_connect6_test.csv and ./lgbm_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.926696
#  Kendall's correlation score: 0.680108
#  Spearman's correlation score: 0.856222
#  Kolmogorov-Smirnov test:    KS-stat = 0.331997    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.857092
#  Kendall's correlation score: 0.459016
#  Spearman's correlation score: 0.633790
#  Kolmogorov-Smirnov test:    KS-stat = 0.577486    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.937333
#  Kendall's correlation score: 0.579864
#  Spearman's correlation score: 0.756432
#  Kolmogorov-Smirnov test:    KS-stat = 0.587129    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.711283
#  Kendall's correlation score: 0.441046
#  Spearman's correlation score: 0.620126
#  Kolmogorov-Smirnov test:    KS-stat = 0.414530    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.901324
#  Kendall's correlation score: 0.601954
#  Spearman's correlation score: 0.785277
#  Kolmogorov-Smirnov test:    KS-stat = 0.541224    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.839733
#  Kendall's correlation score: 0.500139
#  Spearman's correlation score: 0.687123
#  Kolmogorov-Smirnov test:    KS-stat = 0.555725    p-value = 0.000e+00
#
#
#  Relation Between : ./three_grucnn_1connect3_test.csv and ./lgbm_clean_test.csv
#
#  Class: toxic
#  Pearson's correlation score: 0.922172
#  Kendall's correlation score: 0.704192
#  Spearman's correlation score: 0.877909
#  Kolmogorov-Smirnov test:    KS-stat = 0.307559    p-value = 0.000e+00
#
#
#  Class: severe_toxic
#  Pearson's correlation score: 0.841446
#  Kendall's correlation score: 0.540405
#  Spearman's correlation score: 0.725622
#  Kolmogorov-Smirnov test:    KS-stat = 0.670797    p-value = 0.000e+00
#
#
#  Class: obscene
#  Pearson's correlation score: 0.936739
#  Kendall's correlation score: 0.636442
#  Spearman's correlation score: 0.814134
#  Kolmogorov-Smirnov test:    KS-stat = 0.571309    p-value = 0.000e+00
#
#
#  Class: threat
#  Pearson's correlation score: 0.731907
#  Kendall's correlation score: 0.474303
#  Spearman's correlation score: 0.662536
#  Kolmogorov-Smirnov test:    KS-stat = 0.560967    p-value = 0.000e+00
#
#
#  Class: insult
#  Pearson's correlation score: 0.896211
#  Kendall's correlation score: 0.642502
#  Spearman's correlation score: 0.826784
#  Kolmogorov-Smirnov test:    KS-stat = 0.546408    p-value = 0.000e+00
#
#
#  Class: identity_hate
#  Pearson's correlation score: 0.820571
#  Kendall's correlation score: 0.551458
#  Spearman's correlation score: 0.745529
#  Kolmogorov-Smirnov test:    KS-stat = 0.593462    p-value = 0.000e+00
#
# total number of comparison: 171

# %%
##cross validation score 5 fold
# !python stack_same_fold.py
# Out:
# /home/tcs/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# shape is:
# (153164, 72)
# Fit toxic
# 0 [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 60, 66]
# starting cross validation with 5 kfolds
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 1/5): 0.986739
# rows 153164 columns 12
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 2/5): 0.986360
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 3/5): 0.987630
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 4/5): 0.986680
# rows 153164 columns 12
#  train size: 127658. test size: 31913, cols: 12
# size train: 127658 size cv: 31913 AUC (fold 5/5): 0.987784
# rows 153164 columns 12
#  Average AUC: 0.987038
# Fit severe_toxic
# 1 [1, 7, 13, 19, 25, 31, 37, 43, 49, 55, 61, 67]
# starting cross validation with 5 kfolds
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 1/5): 0.992422
# rows 153164 columns 12
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 2/5): 0.989786
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 3/5): 0.990997
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 4/5): 0.991156
# rows 153164 columns 12
#  train size: 127658. test size: 31913, cols: 12
# size train: 127658 size cv: 31913 AUC (fold 5/5): 0.991447
# rows 153164 columns 12
#  Average AUC: 0.991162
# Fit obscene
# 2 [2, 8, 14, 20, 26, 32, 38, 44, 50, 56, 62, 68]
# starting cross validation with 5 kfolds
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 1/5): 0.995351
# rows 153164 columns 12
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 2/5): 0.995044
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 3/5): 0.995039
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 4/5): 0.995198
# rows 153164 columns 12
#  train size: 127658. test size: 31913, cols: 12
# size train: 127658 size cv: 31913 AUC (fold 5/5): 0.995620
# rows 153164 columns 12
#  Average AUC: 0.995250
# Fit threat
# 3 [3, 9, 15, 21, 27, 33, 39, 45, 51, 57, 63, 69]
# starting cross validation with 5 kfolds
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 1/5): 0.993415
# rows 153164 columns 12
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 2/5): 0.991485
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 3/5): 0.993058
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 4/5): 0.995142
# rows 153164 columns 12
#  train size: 127658. test size: 31913, cols: 12
# size train: 127658 size cv: 31913 AUC (fold 5/5): 0.995210
# rows 153164 columns 12
#  Average AUC: 0.993662
# Fit insult
# 4 [4, 10, 16, 22, 28, 34, 40, 46, 52, 58, 64, 70]
# starting cross validation with 5 kfolds
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 1/5): 0.988214
# rows 153164 columns 12
#  train size: 127656. test size: 31915, cols: 12
# size train: 127656 size cv: 31915 AUC (fold 2/5): 0.988719
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 3/5): 0.990536
# rows 153164 columns 12
#  train size: 127657. test size: 31914, cols: 12
# size train: 127657 size cv: 31914 AUC (fold 4/5): 0.989288
# rows 153164 columns 12
#  train size: 127658. test size: 31913, cols: 12
# size train: 127658 size cv: 31913 AUC (fold 5/5): 0.989358
# rows 153164 columns 12
#  Average AUC: 0.989223
# Fit identity_hate
# 5 [5, 11, 17, 23, 29, 35, 41, 47, 53, 59, 65]
# starting cross validation with 5 kfolds
#  train size: 127656. test size: 31915, cols: 11
# size train: 127656 size cv: 31915 AUC (fold 1/5): 0.991150
# rows 153164 columns 11
#  train size: 127656. test size: 31915, cols: 11
# size train: 127656 size cv: 31915 AUC (fold 2/5): 0.986678
# rows 153164 columns 11
#  train size: 127657. test size: 31914, cols: 11
# size train: 127657 size cv: 31914 AUC (fold 3/5): 0.991225
# rows 153164 columns 11
#  train size: 127657. test size: 31914, cols: 11
# size train: 127657 size cv: 31914 AUC (fold 4/5): 0.992722
# rows 153164 columns 11
#  train size: 127658. test size: 31913, cols: 11
# size train: 127658 size cv: 31913 AUC (fold 5/5): 0.993245
# rows 153164 columns 11
#  Average AUC: 0.991004
#  printing test datasets in stack_same_fold_0.9910039905850814.csv
# Done.
